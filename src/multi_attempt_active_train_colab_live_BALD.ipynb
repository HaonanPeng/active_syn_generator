# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun Jul 18 03:16:21 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import sys
path_workspace = '/content/active_learning_v1'
path_source = '/content/drive/MyDrive/active_learning_ws/active_learning_v1'
sys.path.append(path_source)

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.13.1
# !pip install tensorflow-gpu==1.13.1
# Out:
# Collecting tensorflow==1.13.1
#   Downloading https://files.pythonhosted.org/packages/d4/29/6b4f1e02417c3a1ccc85380f093556ffd0b35dc354078074c5195c8447f2/tensorflow-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (92.6MB)
#      |████████████████████████████████| 92.6MB 1.2MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.34.1)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
#      |████████████████████████████████| 368kB 49.0MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (3.17.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.19.5)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 33.5MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.36.2)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.8MB/s
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.12.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.4.0)
# Collecting mock>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/5c/03/b7e605db4a57c0f6fba744b11ef3ddf4ddebcada35022927a2b5fc623fdf/mock-4.0.3-py3-none-any.whl
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.3.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (3.1.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (4.6.1)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow==1.13.1) (1.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.5.0)
# ERROR: kapre 0.3.5 has requirement tensorflow>=2.0.0, but you'll have tensorflow 1.13.1 which is incompatible.
# Installing collected packages: mock, tensorflow-estimator, tensorboard, keras-applications, tensorflow
#   Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# Successfully installed keras-applications-1.0.8 mock-4.0.3 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0
# Collecting tensorflow-gpu==1.13.1
#   Downloading https://files.pythonhosted.org/packages/2c/65/8dc8fc4a263a24f7ad935b72ad35e72ba381cb9e175b6a5fe086c85f17a7/tensorflow_gpu-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (345.0MB)
#      |████████████████████████████████| 345.0MB 34kB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.1.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.15.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.19.5)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.4.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (3.17.3)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.13.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (0.36.2)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.13.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.13.1) (1.34.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (3.1.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.1) (4.0.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.3.4)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (1.5.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (4.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.7.4.3)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.13.1

# %%
import shutil
# !mkdir '/content/active_learning_v1'

shutil.copy("/content/drive/MyDrive/active_learning_ws/active_learning_v1/labels.json", 
            "/content/active_learning_v1/labels.json")

# !unzip -q "/content/drive/MyDrive/active_learning_ws/data/database_folder12_l.zip" -d '/content/active_learning_v1'
# !unzip -q "/content/drive/MyDrive/active_learning_ws/data/background_for_syn_folder12_l.zip" -d '/content/active_learning_v1'
# !unzip -q "/content/drive/MyDrive/active_learning_ws/active_learning_v1/mobilenet_v1_1.0_224.zip" -d '/content/active_learning_v1'

# %%
import os
import numpy as np
import cv2
#from model import *
from model_mobilenet_no_mafa import *
from utils import *
import tensorflow as tf
import time
import shutil
import evaluation_contour


from PIL import Image
import active_learner as al
import active_syn_generator as asg
from generator_utils import rand_from_range
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
active_iterations = 3

proportion_labeled = 0.005
proportion_test = 0.0

head_query_per_iter = 0.00
query_skip = 2
random_query_per_iter = 0.0025
query_per_iter = head_query_per_iter + random_query_per_iter

syn1_per_query = 2
syn2_per_query = 0
multi_gen = 1

border_fusion = True
extract_dilation = 15
fusion_blur = (10, 15)

min_epoch = 20
max_epoch = 5000
epoch = 20 + int(20/(proportion_labeled + (active_iterations-1)*query_per_iter*(1 + syn1_per_query+syn2_per_query)))
epoch = np.max((min_epoch, epoch))
epoch = np.min((max_epoch, epoch))
# epoch = 5

init_bkgd = True
generate_bkgd = False

img_size = (240,240)
batch_size = 16
check_point_folder_name = '/DeepLab_' + str(batch_size) + '_' + str(img_size[1]) + '_' + str(img_size[0])

final_vali_rst = []
final_test_dice = []
final_test_iou = []
final_test_iou_nb = []
final_test_iou_rs = []

for attempt in range(1, 6):
  folder_workspace = None
  active_learner1 = None
  active_syn_generator1 = None
  if attempt == 1:
    al.create_folder(path_workspace)
    folder_workspace = path_workspace + '/active_learning_try1'
    if os.path.isdir(folder_workspace):
        print('workspace already exist, please change a new one')
        sys.exit()
    al.create_folder(folder_workspace)

    # %cp -ar '/content/active_learning_v1/raw_data_base' '/content/active_learning_v1/active_learning_try1'
    # %cp -ar '/content/active_learning_v1/test_set' '/content/active_learning_v1/active_learning_try1'
    # %cp -ar '/content/active_learning_v1/init_background' '/content/active_learning_v1/active_learning_try1'

    random_seed = 13

  if attempt == 2:
    al.create_folder(path_workspace)
    folder_workspace = path_workspace + '/active_learning_try2'
    if os.path.isdir(folder_workspace):
        print('workspace already exist, please change a new one')
        sys.exit()
    al.create_folder(folder_workspace)

    # %cp -ar '/content/active_learning_v1/raw_data_base' '/content/active_learning_v1/active_learning_try2'
    # %cp -ar '/content/active_learning_v1/test_set' '/content/active_learning_v1/active_learning_try2'
    # %cp -ar '/content/active_learning_v1/init_background' '/content/active_learning_v1/active_learning_try2'

    random_seed = 23

  if attempt == 3:
    al.create_folder(path_workspace)
    folder_workspace = path_workspace + '/active_learning_try3'
    if os.path.isdir(folder_workspace):
        print('workspace already exist, please change a new one')
        sys.exit()
    al.create_folder(folder_workspace)

    # %cp -ar '/content/active_learning_v1/raw_data_base' '/content/active_learning_v1/active_learning_try3'
    # %cp -ar '/content/active_learning_v1/test_set' '/content/active_learning_v1/active_learning_try3'
    # %cp -ar '/content/active_learning_v1/init_background' '/content/active_learning_v1/active_learning_try3'

    random_seed = 33

  if attempt == 4:
    al.create_folder(path_workspace)
    folder_workspace = path_workspace + '/active_learning_try4'
    if os.path.isdir(folder_workspace):
        print('workspace already exist, please change a new one')
        sys.exit()
    al.create_folder(folder_workspace)

    # %cp -ar '/content/active_learning_v1/raw_data_base' '/content/active_learning_v1/active_learning_try4'
    # %cp -ar '/content/active_learning_v1/test_set' '/content/active_learning_v1/active_learning_try4'
    # %cp -ar '/content/active_learning_v1/init_background' '/content/active_learning_v1/active_learning_try4'

    random_seed = 43

  if attempt == 5:
    al.create_folder(path_workspace)
    folder_workspace = path_workspace + '/active_learning_try5'
    if os.path.isdir(folder_workspace):
        print('workspace already exist, please change a new one')
        sys.exit()
    al.create_folder(folder_workspace)

    # %cp -ar '/content/active_learning_v1/raw_data_base' '/content/active_learning_v1/active_learning_try5'
    # %cp -ar '/content/active_learning_v1/test_set' '/content/active_learning_v1/active_learning_try5'
    # %cp -ar '/content/active_learning_v1/init_background' '/content/active_learning_v1/active_learning_try5'

    random_seed = 53



  show_img = False # for debug, not working for ubuntu


  tf.set_random_seed(random_seed)
  random.seed(random_seed)
  np.random.seed(random_seed)

  start_time = time.time()

  active_learner1 = al.active_learner()
  active_learner1.folder_workspace = folder_workspace
  active_learner1.init_active_learner(proportion_test = proportion_test, 
                                      proportion_labeled = proportion_labeled, 
                                      query_criterion = 'BALD')

  active_syn_generator1 = asg.active_syn_generator()
  active_syn_generator1.init_syn_img_generator(folder_learn_iter = active_learner1.folder_learn_iter[0],
                                              extract_dilation = extract_dilation, 
                                              img_size = img_size,
                                              init_bkgd = init_bkgd, 
                                              generate_bkgd = generate_bkgd,
                                              output_process = False)

  vali_evaluation_result = []
  test_dice = []
  test_iou = []
  test_iou_nb = []
  test_iou_rs = []

  for a_iter in range(0, active_iterations):
      active_learner1.cur_iter = a_iter
      if a_iter==0:
          active_syn_generator1.load_tool_and_bkgd()
          active_syn_generator1.generate_background()
          #active_syn_generator1.load_tool_and_bkgd()
          query_img_list_ = al.get_file_names(active_learner1.folder_query_added[a_iter] + '/images', 'jpg')
          
          for query_img_file in query_img_list_:
              query_label_file = query_img_file[:-3] + 'png'
              
              image = cv2.imread(active_learner1.folder_query_added[a_iter] + '/images/' + query_img_file)
              label = cv2.imread(active_learner1.folder_query_added[a_iter] + '/labels/' + query_label_file, cv2.IMREAD_GRAYSCALE)
              
              if np.sum(label) < 40: # if the query image has no tool or only a small tool
                  continue
              active_syn_generator1.file_name = query_img_file[:-4]
              
              syn1_images_, syn1_labels_, syn2_images_, syn2_labels_ = active_syn_generator1.generate_syn_img(image, label, dilation = extract_dilation,
                                                                                                              syn1 = syn1_per_query, syn2 = syn2_per_query, 
                                                                                                              multi_gen = multi_gen,                                                                                           
                                                                                  flip=(0.1, 0.8), 
                                                                                  shrink_factor=(0.9, 1.2), 
                                                                                  x_factor=(-0.1, 0.1), 
                                                                                  y_factor=(-0.1, 0.1), 
                                                                                  r_factor=(-30, 30), 
                                                                                  color_adjust_strength=(0.4, 1.0), 
                                                                                  brightness_adjust=(0.9, 1.3), 
                                                                                  border_fusion = border_fusion,
                                                                                  fusion_blur= fusion_blur, 
                                                                                  border_center=((115,125), (115,125)), 
                                                                                  radius=(150,170), 
                                                                                  ksize=(1,3), 
                                                                                  sig_x=(-10,3),
                                                                                  elastic= (-2, -1), 
                                                                                  els_alpha=(2000, 3000), 
                                                                                  els_sigma=(10, 15), 
                                                                                  dila_ero=(-0.5, 0.5), 
                                                                                  val_type=0, 
                                                                                  dila_ero_size=(1, 2), 
                                                                                  img_elastic=(-4, -1), 
                                                                                  img_els_alpha=(2000, 3000), 
                                                                                  img_els_sigma=(10, 15),
                                                                                  img_size = img_size,
                                                                                  show_img = show_img)
              al.create_folder(active_learner1.folder_query_added[a_iter] + '/img_n_gt')
              count = 0
              for syn1_image in syn1_images_:
                  syn1_label = syn1_labels_[count]
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/images/' + query_img_file[:-4] + '_syn1_' + str(count) + '.jpg', syn1_image)
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/labels/' + query_img_file[:-4] + '_syn1_' + str(count) + '.png', syn1_label)
                  count = count + 1
                  
                  ground_truth = np.zeros(syn1_image.shape)
                  ground_truth[:,:,1] = (syn1_label * 250).clip(0,255).astype(np.uint8)
                  img_n_gt = np.hstack((syn1_image, ground_truth))
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/img_n_gt/' + query_img_file[:-4] + '_syn1_' + str(count) + '.jpg', img_n_gt)
                  
              count = 0
              for syn2_image in syn2_images_:
                  syn2_label = syn2_labels_[count]
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/images/' + query_img_file[:-4] + '_syn2_' + str(count) + '.jpg', syn2_image)
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/labels/' + query_img_file[:-4] + '_syn2_' + str(count) + '.png', syn2_label)
                  count = count + 1
                  
                  ground_truth = np.zeros(syn2_image.shape)
                  ground_truth[:,:,1] = (syn2_label * 250).clip(0,255).astype(np.uint8)
                  img_n_gt = np.hstack((syn2_image, ground_truth))
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/img_n_gt/' + query_img_file[:-4] + '_syn2_' + str(count) + '.jpg', img_n_gt)
          al.copy_folder2(active_learner1.folder_query_added[a_iter], active_learner1.folder_labeled[a_iter])  

      if a_iter>0:
          active_learner1.create_folders(iteration = a_iter)
          active_learner1.inherit_from_previous_iter()
          
          active_syn_generator1.init_new_iteration(iteration = a_iter, 
                                                  folder_learn_iter = active_learner1.folder_learn_iter[a_iter], 
                                                  dilation = extract_dilation)
          
          active_syn_generator1.load_tool_and_bkgd()
          
          query_img_list_ = al.get_file_names(active_learner1.folder_query_added[a_iter] + '/images', 'jpg')
          
          for query_img_file in query_img_list_:
              query_label_file = query_img_file[:-3] + 'png'
              
              image = cv2.imread(active_learner1.folder_query_added[a_iter] + '/images/' + query_img_file)
              label = cv2.imread(active_learner1.folder_query_added[a_iter] + '/labels/' + query_label_file, cv2.IMREAD_GRAYSCALE)
              
              if np.sum(label) < 40: # if the query image has no tool or only 
                  continue
          
              syn1_images_, syn1_labels_, syn2_images_, syn2_labels_ = active_syn_generator1.generate_syn_img(image, label, dilation = extract_dilation,
                                                                                                              syn1 = syn1_per_query, syn2 = syn2_per_query, 
                                                                                                              multi_gen = multi_gen,                                                                                           
                                                                                  flip=(0.1, 0.8), 
                                                                                  shrink_factor=(0.9, 1.2), 
                                                                                  x_factor=(-0.1, 0.1), 
                                                                                  y_factor=(-0.1, 0.1), 
                                                                                  r_factor=(-30, 30), 
                                                                                  color_adjust_strength=(0.4, 1.0), 
                                                                                  brightness_adjust=(0.9, 1.3),
                                                                                  border_fusion = border_fusion, 
                                                                                  fusion_blur= fusion_blur, 
                                                                                  border_center=((115,125), (115,125)), 
                                                                                  radius=(150,170), 
                                                                                  ksize=(1,3), 
                                                                                  sig_x=(-10,3),
                                                                                  elastic= (-2, -1), 
                                                                                  els_alpha=(2000, 3000), 
                                                                                  els_sigma=(10, 15), 
                                                                                  dila_ero=(-0.5, 0.5), 
                                                                                  val_type=0, 
                                                                                  dila_ero_size=(1, 2), 
                                                                                  img_elastic=(-4, -1), 
                                                                                  img_els_alpha=(2000, 3000), 
                                                                                  img_els_sigma=(10, 15),
                                                                                  img_size = img_size,
                                                                                  show_img = show_img)
              al.create_folder(active_learner1.folder_query_added[a_iter] + '/img_n_gt')
              count = 0
              for syn1_image in syn1_images_:
                  syn1_label = syn1_labels_[count]
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/images/' + query_img_file[:-4] + '_syn1_' + str(count) + '.jpg', syn1_image)
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/labels/' + query_img_file[:-4] + '_syn1_' + str(count) + '.png', syn1_label)
                  count = count + 1
                  
                  ground_truth = np.zeros(syn1_image.shape)
                  ground_truth[:,:,1] = (syn1_label * 250).clip(0,255).astype(np.uint8)
                  img_n_gt = np.hstack((syn1_image, ground_truth))
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/img_n_gt/' + query_img_file[:-4] + '_syn1_' + str(count) + '.jpg', img_n_gt)
                  
              count = 0
              for syn2_image in syn2_images_:
                  syn2_label = syn2_labels_[count]
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/images/' + query_img_file[:-4] + '_syn2_' + str(count) + '.jpg', syn2_image)
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/labels/' + query_img_file[:-4] + '_syn2_' + str(count) + '.png', syn2_label)
                  count = count + 1
                  
                  ground_truth = np.zeros(syn2_image.shape)
                  ground_truth[:,:,1] = (syn2_label * 250).clip(0,255).astype(np.uint8)
                  img_n_gt = np.hstack((syn2_image, ground_truth))
                  cv2.imwrite(active_learner1.folder_query_added[a_iter] + '/img_n_gt/' + query_img_file[:-4] + '_syn2_' + str(count) + '.jpg', img_n_gt)
          al.copy_folder2(active_learner1.folder_query_added[a_iter], active_learner1.folder_labeled[a_iter])
                            
  # Training CNN -----------------------------------------------------------------------------------
      def del_all_flags(FLAGS):
          flags_dict = FLAGS._flags()
          keys_list = [keys for keys in flags_dict]
          for keys in keys_list:
              FLAGS.__delattr__(keys)
      del_all_flags(tf.flags.FLAGS)
      tf.reset_default_graph()
      tf.set_random_seed(random_seed)
      
      flags = tf.app.flags
      tf.app.flags.DEFINE_string('f', '', 'kernel')
      print('||||||||||||||||||||||||||||||||||')
      print('current epoch:')
      print(str(epoch))
      print('||||||||||||||||||||||||||||||||||')
      
      flags.DEFINE_integer("epoch", int(epoch), "Epoch to train [25]")
      
      # flags.DEFINE_integer("epoch",epoch, "Epoch to train [25]")
      flags.DEFINE_integer("batch_size", batch_size, "The size of batch images [64]")
      flags.DEFINE_integer("input_height", img_size[1], "The size of image to use (will be center cropped). [108]")
      flags.DEFINE_integer("input_width", img_size[0], "The size of image to use (will be center cropped). If None, same value as input_height [None]")
      
      # the folder of training set and validation set, must contain a sub-folder called 'images' and a sub-folder called 'labels' 
      flags.DEFINE_string("train_dataset", active_learner1.folder_labeled[a_iter], "train dataset direction")
      flags.DEFINE_string("val_dataset", active_learner1.folder_unlabeled[a_iter], "train dataset direction")
      
      flags.DEFINE_string("img_pattern", "*.jpg", "Glob pattern of filename of input images [*]")
      flags.DEFINE_string("label_pattern", "*.png", "Glob pattern of filename of input labels [*]")
      flags.DEFINE_string("checkpoint_dir", active_learner1.folder_checkpoint[a_iter], "Directory name to save the checkpoints [checkpoint]")
      flags.DEFINE_string("pretrain_dir", path_workspace + "/mobilenet_v1_1.0_224", "")
      flags.DEFINE_string("gpu", '0', "gpu")
      FLAGS = flags.FLAGS
      
      pp.pprint(flags.FLAGS.__flags)
      
      print(active_learner1.folder_checkpoint[a_iter])
      if not os.path.exists(FLAGS.checkpoint_dir):
        os.makedirs(FLAGS.checkpoint_dir)
      #al.create_folder(active_learner1.folder_checkpoint[a_iter])
        
      color_table = load_color_table(path_workspace + '/labels.json')
      #gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
      run_config = tf.ConfigProto()
      run_config.gpu_options.allow_growth=True
      tf.reset_default_graph()
      with tf.Session(config=run_config) as sess:
        
        net = DeepLab(
              sess,
              input_width=FLAGS.input_width,
              input_height=FLAGS.input_height,
              batch_size=FLAGS.batch_size,
              img_pattern=FLAGS.img_pattern,
              label_pattern=FLAGS.label_pattern,
              checkpoint_dir=FLAGS.checkpoint_dir,
              pretrain_dir=FLAGS.pretrain_dir,
              train_dataset=FLAGS.train_dataset,
              val_dataset=FLAGS.val_dataset,
              num_class=2,
              color_table=color_table,is_train=True)
        
        net.train(FLAGS)
          
  # Evaluating CNN and query labeling using validation (unlabeled data)-----------------------------------------------------------------------
      def del_all_flags(FLAGS):
          flags_dict = FLAGS._flags()
          keys_list = [keys for keys in flags_dict]
          for keys in keys_list:
              FLAGS.__delattr__(keys)
      del_all_flags(tf.flags.FLAGS)
      tf.reset_default_graph()
      
      flags = tf.app.flags
      tf.app.flags.DEFINE_string('f', '', 'kernel')
      flags.DEFINE_string("train_dataset", active_learner1.folder_labeled[a_iter], "train dataset direction")
      flags.DEFINE_string("val_dataset", active_learner1.folder_unlabeled[a_iter], "val dataset direction")
      flags.DEFINE_string("checkpoint_dir", active_learner1.folder_checkpoint[a_iter] + check_point_folder_name, "checkpoint")
      flags.DEFINE_string("img_dir", active_learner1.folder_unlabeled[a_iter] + '/images', "img_dir")
      flags.DEFINE_string("rst_dir", active_learner1.folder_learn_iter[a_iter] + "/vali-rsts", "rst_dir")
      flags.DEFINE_string("gt_dir", active_learner1.folder_unlabeled[a_iter] + '/labels', "gt_dir")
      flags.DEFINE_string("rst_file", active_learner1.folder_learn_iter[a_iter] + "_vali_rst.txt", "gt_dir")
      flags.DEFINE_string("gpu", '0', "gpu")
      FLAGS = flags.FLAGS
      
      os.environ['CUDA_VISIBLE_DEVICES'] = FLAGS.gpu
      
      test_all=True
      color_table = load_color_table(path_workspace + '/labels.json')
      run_config = tf.ConfigProto()
      sess=tf.Session(config=run_config)
      with tf.variable_scope(tf.get_variable_scope(), reuse=tf.AUTO_REUSE):
          net = DeepLab(
                sess,
                input_width=img_size[0],
                input_height=img_size[1],
                batch_size=1,
                img_pattern="*.jpg",
                label_pattern="*.png",
                checkpoint_dir=FLAGS.checkpoint_dir,
                pretrain_dir='',
                train_dataset=FLAGS.train_dataset,
                val_dataset=FLAGS.val_dataset,
                num_class=2,
                color_table=color_table,is_train=False)
          if not net.load(net.checkpoint_dir)[0]:
              raise Exception("Cannot find checkpoint!")
              
          if test_all:
          
              #test on train
              img_dir = FLAGS.img_dir
              rst_dir = FLAGS.rst_dir
              gt_dir = FLAGS.gt_dir
              
              if not os.path.exists(rst_dir):
                  os.makedirs(rst_dir)
      
              
              files=os.listdir(img_dir)
              for i,file in enumerate(files):
                  if not file.endswith(".jpg"):
                      continue
                  
                  
                  img = cv2.imread(os.path.join(img_dir,file))

                  # Monte Carlo query method here
                  MCDP_times = 10

                  mean_out_put_pd = np.zeros((img_size[1], img_size[0], 2))
                  BALD_img_pd_ = []
                  for MC_iter in range(0, MCDP_times):
                    tf.set_random_seed(11*MC_iter + random_seed)
                    random.seed(11*MC_iter + random_seed)
                    np.random.seed(11*MC_iter + random_seed)
                    idxmap, colormap, out_put_pd = net.inference(img, drop_out = 0.5)  
                    BALD_img_pd_.append(out_put_pd)
                    mean_out_put_pd = mean_out_put_pd + (1/MCDP_times) * out_put_pd
                  
                  tf.set_random_seed(random_seed)
                  random.seed(random_seed)
                  np.random.seed(random_seed)
                  active_learner1.add_instance(img_pd = mean_out_put_pd, file_name = file, BALD_img_pd_ = BALD_img_pd_)
                  # al.show_prob_distribution('image_porb', out_put_pd)
                  
                  colormap=cv2.cvtColor(colormap,cv2.COLOR_RGB2BGR)
                  
                  cv2.imwrite(os.path.join(rst_dir,file[:-4]+'.png'),colormap) 
                  
              mean_dice, mean_iou = evaluate_seg_result(rst_dir, gt_dir, FLAGS.rst_file)
              
              vali_evaluation_result.append([mean_dice, mean_iou])
              
              active_learner1.sort_query_list()
              active_learner1.show_query_list(head = 10)
              active_learner1.select_query(head_query = head_query_per_iter, skip = query_skip, random_query = random_query_per_iter)
              
  # Evaluating CNN and using test set-----------------------------------------------------------------------
      def del_all_flags(FLAGS):
          flags_dict = FLAGS._flags()
          keys_list = [keys for keys in flags_dict]
          for keys in keys_list:
              FLAGS.__delattr__(keys)
      del_all_flags(tf.flags.FLAGS)
      tf.reset_default_graph()
      
      
      flags = tf.app.flags
      tf.app.flags.DEFINE_string('f', '', 'kernel')
      flags.DEFINE_string("train_dataset", active_learner1.folder_labeled[a_iter], "train dataset direction")
      flags.DEFINE_string("val_dataset", active_learner1.folder_unlabeled[a_iter], "val dataset direction")
      flags.DEFINE_string("checkpoint_dir", active_learner1.folder_checkpoint[a_iter] + check_point_folder_name, "checkpoint")
      flags.DEFINE_string("img_dir", active_learner1.folder_test_set + '/images', "img_dir")
      flags.DEFINE_string("rst_dir", active_learner1.folder_learn_iter[a_iter] + "/test-rsts", "rst_dir")
      flags.DEFINE_string("gt_dir", active_learner1.folder_test_set + '/labels', "gt_dir")
      flags.DEFINE_string("rst_file", active_learner1.folder_learn_iter[a_iter] + "_test_rst.txt", "gt_dir")
      flags.DEFINE_string("gpu", '0', "gpu")
      FLAGS = flags.FLAGS
      
      os.environ['CUDA_VISIBLE_DEVICES'] = FLAGS.gpu
      
      test_all=True
      color_table = load_color_table(path_workspace + '/labels.json')
      run_config = tf.ConfigProto()
      sess=tf.Session(config=run_config)
      with tf.variable_scope(tf.get_variable_scope(), reuse=tf.AUTO_REUSE):
          net = DeepLab(
                sess,
                input_width=img_size[0],
                input_height=img_size[1],
                batch_size=1,
                img_pattern="*.jpg",
                label_pattern="*.png",
                checkpoint_dir=FLAGS.checkpoint_dir,
                pretrain_dir='',
                train_dataset=FLAGS.train_dataset,
                val_dataset=FLAGS.val_dataset,
                num_class=2,
                color_table=color_table,is_train=False)
          if not net.load(net.checkpoint_dir)[0]:
              raise Exception("Cannot find checkpoint!")
              
          if test_all:
          
              #test on train
              img_dir = FLAGS.img_dir
              rst_dir = FLAGS.rst_dir
              gt_dir = FLAGS.gt_dir
              
              if not os.path.exists(rst_dir):
                  os.makedirs(rst_dir)
      
              
              files=os.listdir(img_dir)
              for i,file in enumerate(files):
                  if not file.endswith(".jpg"):
                      continue
                  
                  
                  img = cv2.imread(os.path.join(img_dir,file))
                  # print(img_dir)
                  # print(file)
                  
                  idxmap, colormap, out_put_pd = net.inference(img)  
                  
                  # active_learner1.add_instance(img_pd = out_put_pd, file_name = file)
                  # al.show_prob_distribution('image_porb', out_put_pd)
                  
                  colormap=cv2.cvtColor(colormap,cv2.COLOR_RGB2BGR)
                  
                  cv2.imwrite(os.path.join(rst_dir,file[:-4]+'.png'),colormap) 
                  
              mean_dice, mean_iou = evaluate_seg_result(rst_dir, gt_dir, FLAGS.rst_file)

              m_iou_nb = evaluation_contour.evaluate_IOU_nearContour(output_path = active_learner1.folder_learn_iter[a_iter] + "/test-rsts",
                                                                     image_path = active_learner1.folder_test_set + '/images',
                                                                     label_path = active_learner1.folder_test_set + '/labels')
              test_dice.append(mean_dice)
              test_iou.append(mean_iou)
              test_iou_nb.append(m_iou_nb)

              def del_all_flags(FLAGS):
                  flags_dict = FLAGS._flags()
                  keys_list = [keys for keys in flags_dict]
                  for keys in keys_list:
                      FLAGS.__delattr__(keys)
              del_all_flags(tf.flags.FLAGS)
              # tf.reset_default_graph()


              flags = tf.app.flags
              tf.app.flags.DEFINE_string('f', '', 'kernel')
              flags.DEFINE_string("train_dataset", active_learner1.folder_labeled[a_iter], "train dataset direction")
              flags.DEFINE_string("val_dataset", active_learner1.folder_unlabeled[a_iter], "val dataset direction")
              flags.DEFINE_string("checkpoint_dir", active_learner1.folder_checkpoint[a_iter] + check_point_folder_name, "checkpoint")
              flags.DEFINE_string("img_dir", active_learner1.folder_test_set + '/images', "img_dir")
              flags.DEFINE_string("rst_dir", active_learner1.folder_learn_iter[a_iter] + "/test-rsts", "rst_dir")
              flags.DEFINE_string("gt_dir", active_learner1.folder_test_set + '/labels', "gt_dir")
              flags.DEFINE_string("rst_file", active_learner1.folder_learn_iter[a_iter] + "_test_rst.txt", "gt_dir")
              flags.DEFINE_string("gpu", '0', "gpu")
              FLAGS = flags.FLAGS


              os.environ['CUDA_VISIBLE_DEVICES'] = FLAGS.gpu
              test_all=True
              color_table = load_color_table(path_workspace + '/labels.json')
              run_config = tf.ConfigProto()
              sess=tf.Session(config=run_config)
              with tf.variable_scope(tf.get_variable_scope(), reuse=tf.AUTO_REUSE):
                  net = DeepLab(
                        sess,
                        input_width=img_size[0],
                        input_height=img_size[1],
                        batch_size=1,
                        img_pattern="*.jpg",
                        label_pattern="*.png",
                        checkpoint_dir=FLAGS.checkpoint_dir,
                        pretrain_dir='',
                        train_dataset=FLAGS.train_dataset,
                        val_dataset=FLAGS.val_dataset,
                        num_class=2,
                        color_table=color_table,is_train=False)
                  if not net.load(net.checkpoint_dir)[0]:
                      raise Exception("Cannot find checkpoint!")
                      
                  
                  
                  if test_all:
                  
                      #test on train
                      img_dir = FLAGS.img_dir
                      rst_dir = FLAGS.rst_dir
                      gt_dir = FLAGS.gt_dir
                      if not os.path.exists(rst_dir):
                          os.makedirs(rst_dir)

                      
                      files=os.listdir(img_dir)
                      stds_iou = []
                      means_iou = []
                      for i,file in enumerate(files):
                          if not file.endswith(".jpg"):
                              continue
                          
                          ious = []
                          for i in range(6):
                              img = Image.open(os.path.join(img_dir,file))
                              img = img.rotate(i*60)
                              img = np.asarray(img)
                              img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
                              
                              gt = Image.open(os.path.join(gt_dir,file[:-4]+'.png'))
                              gt = gt.rotate(i*60)
                              gt = np.asarray(gt)
                                      
                          
                              idxmap, colormap, out_put_pd = net.inference(img)  
                          
                              gt_=1-gt
                              #     
                              output = cv2.resize(idxmap,(gt.shape[1],gt.shape[0]),interpolation=cv2.INTER_NEAREST)
                              output_=1-output
                          
                              #
                              if (np.count_nonzero(output)+np.count_nonzero(gt)) is 0:
                                  iou = 1
                              else:                        
                                  iou = np.count_nonzero(gt*output)/(np.count_nonzero(output+gt)+0.000001)
                              
                              ious.append(iou)
                          
                          m_iou = np.mean(ious)
                          std_iou = np.std(ious)
                          stds_iou.append(std_iou)
                          means_iou.append(m_iou)
                      # print("mean_iou_mean: {},  mean_iou_var: {}".format(np.mean(means_iou),np.mean(stds_iou)))
                      m_iou_rs = np.mean(means_iou)
                      m_iou_rs_std = np.mean(stds_iou)
              
              
              test_iou_rs.append([m_iou_rs, m_iou_rs_std])



      print('[Active Learner]: Active learning interation complete, completed iteration:' + str(a_iter))
      
  print('Active training ended, validation result:')
  print(vali_evaluation_result)
  print('Active training ended, test results:')
  print('DICE:')
  print(test_dice)
  print('IOU:')
  print(test_iou)
  print('IOU_nb:')
  print(test_iou_nb)
  print('IOU_rs:')
  print(test_iou_rs)

  print('Total time cost(second):')
  print(str(time.time()-start_time))

  final_vali_rst.append(vali_evaluation_result)
  final_test_dice.append(test_dice)
  final_test_iou.append(test_iou)
  final_test_iou_nb.append(test_iou_nb)
  final_test_iou_rs.append(test_iou_rs)
  

# print('Active training ended,fianl validation results of all attemptions:')
# print(final_vali_rst)
print('Active training ended, final test results of all attemptions:')
print('DICE of each trail:')
print(final_test_dice)
print('Final IOU of each trail:')
print(final_test_iou)
print('Final IOU_nb of each trail:')
print(final_test_iou_nb)
# print('Final IOU_rs:')
# print(final_test_iou_rs)

print('Result of the final result:')
print('Dice:')
print(np.array(final_test_dice)[:,-1])
print('IOU:')
print(np.array(final_test_iou)[:,-1])
print('IOU NB:')
print(np.array(final_test_iou_nb)[:,-1])
# Out:
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9d482fe10>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9d482f4d0>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9d482fd50>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9d482f2d0>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9d484c1d0>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9d482f5d0>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9d482f590>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9d482f350>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9d484c050>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9d484c110>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9d482ffd0>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9d482f710>}
# /content/active_learning_v1/active_learning_try1/active_iter0/checkpoint
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/drive/MyDrive/active_learning_ws/active_learning_v1/model_mobilenet_no_mafa.py:188: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/MyDrive/active_learning_ws/active_learning_v1/ops.py:19: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#  [*] Reading checkpoints...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/vali-rsts/L02_51883.png
# mean_dice=0.516736645735168,mean_iou=0.4345999054611651
# [Active Learner]: the maximum entropy select list:
# [{'value': 1855.555793063325, 'file_name': 'L02_69215.jpg'}, {'value': 1551.9635350876933, 'file_name': 'L02_6450.jpg'}, {'value': 1418.2845688011575, 'file_name': 'L02_1500.jpg'}, {'value': 1412.5024601321434, 'file_name': 'L02_94808.jpg'}, {'value': 1391.911945256706, 'file_name': 'L02_85778.jpg'}, {'value': 1288.457375297981, 'file_name': 'L02_11310.jpg'}, {'value': 1236.323942175883, 'file_name': 'L02_1710.jpg'}, {'value': 1216.3210476895774, 'file_name': 'L02_63905.jpg'}, {'value': 1169.236653457332, 'file_name': 'L02_94898.jpg'}, {'value': 1084.0494396176332, 'file_name': 'L02_11640.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.6149097202088339,mean_iou=0.5294613736905157
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try1/active_iter0/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try1/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.5856758189982352,mean_iou=0.47500823829546246
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# [Active Learner]: Active learning interation complete, completed iteration:0
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9d4859510>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9d46f5c10>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9d4859cd0>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9d484c190>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9d46f5190>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9d46f5650>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9d4859090>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9d46f53d0>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9d46f5290>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9d46f5d10>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9d46f55d0>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9d46f5310>}
# /content/active_learning_v1/active_learning_try1/active_iter1/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2080
#  [*] Success to read DeepLab.model-2080
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/vali-rsts/L02_51883.png
# mean_dice=0.4298549715995772,mean_iou=0.3529769452772995
# [Active Learner]: the maximum entropy select list:
# [{'value': 2213.7137108639463, 'file_name': 'L02_11610.jpg'}, {'value': 2014.273975148259, 'file_name': 'L02_17010.jpg'}, {'value': 1522.9419634953665, 'file_name': 'L02_90728.jpg'}, {'value': 1513.3363909995956, 'file_name': 'L02_7290.jpg'}, {'value': 1389.5636146762672, 'file_name': 'L02_91208.jpg'}, {'value': 1340.232546499798, 'file_name': 'L02_79925.jpg'}, {'value': 1301.7589489194474, 'file_name': 'L01_19989.jpg'}, {'value': 1256.4592308401843, 'file_name': 'L02_11760.jpg'}, {'value': 1252.119288182978, 'file_name': 'L02_54133.jpg'}, {'value': 1239.2025803637532, 'file_name': 'L02_64835.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2080
#  [*] Success to read DeepLab.model-2080
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.5457024574347593,mean_iou=0.4653686190082805
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try1/active_iter1/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try1/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.4700977647433426,mean_iou=0.36982792913985113
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2080
#  [*] Success to read DeepLab.model-2080
# [Active Learner]: Active learning interation complete, completed iteration:1
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9c9e09350>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9c9e09f10>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9c9e09750>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9c9e09990>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc98c149090>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc98c149250>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9c9e09a50>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9c9e09c50>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc98c149d10>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc98c1490d0>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc98c149f50>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc98c149ad0>}
# /content/active_learning_v1/active_learning_try1/active_iter2/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/vali-rsts/L02_51883.png
# mean_dice=0.5258641697394378,mean_iou=0.4433159383598588
# [Active Learner]: the maximum entropy select list:
# [{'value': 2331.654563102118, 'file_name': 'L02_11700.jpg'}, {'value': 2212.868182320576, 'file_name': 'L02_11580.jpg'}, {'value': 2129.8537316455104, 'file_name': 'L02_28491.jpg'}, {'value': 2114.908176990977, 'file_name': 'L02_13350.jpg'}, {'value': 1836.1367834720231, 'file_name': 'L02_9900.jpg'}, {'value': 1592.8011564496242, 'file_name': 'L02_6450.jpg'}, {'value': 1570.8230071194903, 'file_name': 'L02_11250.jpg'}, {'value': 1368.614349262828, 'file_name': 'L02_18801.jpg'}, {'value': 1352.2581557741933, 'file_name': 'L02_15690.jpg'}, {'value': 1334.20646431847, 'file_name': 'L02_15930.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try1/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6242105967114424,mean_iou=0.5472601256192745
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try1/active_iter2/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try1/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.5656725213486917,mean_iou=0.4634835689786261
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try1/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# [Active Learner]: Active learning interation complete, completed iteration:2
# Active training ended, validation result:
# [[0.516736645735168, 0.4345999054611651], [0.4298549715995772, 0.3529769452772995], [0.5258641697394378, 0.4433159383598588]]
# Active training ended, test results:
# DICE:
# [0.6149097202088339, 0.5457024574347593, 0.6242105967114424]
# IOU:
# [0.5294613736905157, 0.4653686190082805, 0.5472601256192745]
# IOU_nb:
# [0.47500823829546246, 0.36982792913985113, 0.4634835689786261]
# IOU_rs:
# [[0.4720804716057465, 0.19303290797109743], [0.43241163586108017, 0.2792205148422982], [0.5446855163299937, 0.22484337774282342]]
# Total time cost(second):
# 3637.895001411438
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9c3b3d0d0>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9c3b3d890>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9c3b3de50>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9c3b3d910>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc98d632710>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9c3b3dc50>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9c3b3dd90>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9c3b3db90>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9c3b3d790>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc98d632550>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9c3b3d950>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9c3b3d590>}
# /content/active_learning_v1/active_learning_try2/active_iter0/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/vali-rsts/L02_51883.png
# mean_dice=0.46234258590463306,mean_iou=0.3938988684967544
# [Active Learner]: the maximum entropy select list:
# [{'value': 1920.252196605938, 'file_name': 'L01_13530.jpg'}, {'value': 1812.7460149779372, 'file_name': 'L02_85808.jpg'}, {'value': 1724.6596505382345, 'file_name': 'L02_37221.jpg'}, {'value': 1645.1862561582975, 'file_name': 'L02_570.jpg'}, {'value': 1539.2398656894989, 'file_name': 'L02_88418.jpg'}, {'value': 1530.8189834829286, 'file_name': 'L02_660.jpg'}, {'value': 1505.7586182472205, 'file_name': 'L01_31449.jpg'}, {'value': 1485.9285991740994, 'file_name': 'L02_33651.jpg'}, {'value': 1478.7911839762028, 'file_name': 'L02_510.jpg'}, {'value': 1471.799630916686, 'file_name': 'L02_42733.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.6178914682695235,mean_iou=0.5583551295090197
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try2/active_iter0/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try2/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.5568733082250164,mean_iou=0.46900015941023754
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# [Active Learner]: Active learning interation complete, completed iteration:0
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9c16ca250>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9c959a6d0>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9c16cab10>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9d477c110>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9c959a810>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9c959a250>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9c16ca2d0>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9c16caf90>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9c959a650>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9c959a390>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9c959a990>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9c959ac90>}
# /content/active_learning_v1/active_learning_try2/active_iter1/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2080
#  [*] Success to read DeepLab.model-2080
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/vali-rsts/L02_51883.png
# mean_dice=0.5595871289665807,mean_iou=0.47726379844615485
# [Active Learner]: the maximum entropy select list:
# [{'value': 1724.2360872110612, 'file_name': 'L01_10920.jpg'}, {'value': 1643.6619787258078, 'file_name': 'L02_360.jpg'}, {'value': 1569.2154194779, 'file_name': 'L01_7500.jpg'}, {'value': 1520.6531477213352, 'file_name': 'L02_28791.jpg'}, {'value': 1408.8313387954797, 'file_name': 'L02_7740.jpg'}, {'value': 1400.9849907462894, 'file_name': 'L01_21669.jpg'}, {'value': 1393.7970406950626, 'file_name': 'L01_24789.jpg'}, {'value': 1364.3748106189823, 'file_name': 'L02_65945.jpg'}, {'value': 1355.7866456935085, 'file_name': 'L01_31269.jpg'}, {'value': 1327.7112108751899, 'file_name': 'L01_25899.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2080
#  [*] Success to read DeepLab.model-2080
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.6430344765000894,mean_iou=0.5743097926158467
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try2/active_iter1/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try2/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.579779323875577,mean_iou=0.4829432124951335
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2080
#  [*] Success to read DeepLab.model-2080
# [Active Learner]: Active learning interation complete, completed iteration:1
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9d476dd50>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9d476d590>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9d476d450>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9d476d310>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9d476df50>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9d476dc90>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9d476d150>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9d476d190>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9d476d950>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9d476d610>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9d476d890>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9d476d2d0>}
# /content/active_learning_v1/active_learning_try2/active_iter2/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/vali-rsts/L02_51883.png
# mean_dice=0.6163236159771974,mean_iou=0.5379718209606856
# [Active Learner]: the maximum entropy select list:
# [{'value': 1684.4021155132195, 'file_name': 'L02_150.jpg'}, {'value': 1574.8380572125875, 'file_name': 'L02_62105.jpg'}, {'value': 1458.8512592174188, 'file_name': 'L02_42733.jpg'}, {'value': 1423.3353893959898, 'file_name': 'L01_30339.jpg'}, {'value': 1376.5988374108174, 'file_name': 'L02_92198.jpg'}, {'value': 1236.975567634678, 'file_name': 'L02_62525.jpg'}, {'value': 1217.680018620597, 'file_name': 'L01_26829.jpg'}, {'value': 1213.1716187909196, 'file_name': 'L02_26541.jpg'}, {'value': 1196.5661137210836, 'file_name': 'L02_37221.jpg'}, {'value': 1180.3853736341198, 'file_name': 'L01_2700.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try2/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6977280400991852,mean_iou=0.6314830724663485
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try2/active_iter2/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try2/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6530167448749377,mean_iou=0.5588130416655331
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try2/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# [Active Learner]: Active learning interation complete, completed iteration:2
# Active training ended, validation result:
# [[0.46234258590463306, 0.3938988684967544], [0.5595871289665807, 0.47726379844615485], [0.6163236159771974, 0.5379718209606856]]
# Active training ended, test results:
# DICE:
# [0.6178914682695235, 0.6430344765000894, 0.6977280400991852]
# IOU:
# [0.5583551295090197, 0.5743097926158467, 0.6314830724663485]
# IOU_nb:
# [0.46900015941023754, 0.4829432124951335, 0.5588130416655331]
# IOU_rs:
# [[0.47541682656630246, 0.20648471370927038], [0.5321162804410894, 0.1920309968235117], [0.5696435423489858, 0.21213942938802757]]
# Total time cost(second):
# 3635.906136751175
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fca5ae2c650>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fca5ae2c610>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9d476d350>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9d4703690>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9c95ba4d0>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9c904f990>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fca5ae2c310>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fca5ae2c850>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9c0de3350>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9c95ba410>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9c904ff50>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9c904f710>}
# /content/active_learning_v1/active_learning_try3/active_iter0/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/vali-rsts/L02_51883.png
# mean_dice=0.46963753486276094,mean_iou=0.3882069512645338
# [Active Learner]: the maximum entropy select list:
# [{'value': 1325.891541786571, 'file_name': 'L02_18540.jpg'}, {'value': 1276.407795725665, 'file_name': 'L02_6360.jpg'}, {'value': 1220.1835596884284, 'file_name': 'L01_21699.jpg'}, {'value': 1217.640000500317, 'file_name': 'L02_17490.jpg'}, {'value': 1162.803210820336, 'file_name': 'L02_60793.jpg'}, {'value': 1141.2370207965032, 'file_name': 'L02_7740.jpg'}, {'value': 1101.6981584678088, 'file_name': 'L01_7500.jpg'}, {'value': 1089.7653164519925, 'file_name': 'L01_18489.jpg'}, {'value': 1042.1585231831846, 'file_name': 'L02_65735.jpg'}, {'value': 1040.6447719823113, 'file_name': 'L02_18660.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.611704101429866,mean_iou=0.5256899276061883
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try3/active_iter0/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try3/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.5500476781314622,mean_iou=0.4360659018951839
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# [Active Learner]: Active learning interation complete, completed iteration:0
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9d47067d0>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc98d23ed90>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc789956dd0>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9d477c050>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc98d23e950>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc98d23ecd0>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc98d23eb10>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc98d23e710>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc98d23efd0>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc98d23ef50>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc98d23ea90>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc98d23edd0>}
# /content/active_learning_v1/active_learning_try3/active_iter1/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/vali-rsts/L02_51883.png
# mean_dice=0.5604765747555919,mean_iou=0.47775760372163806
# [Active Learner]: the maximum entropy select list:
# [{'value': 2096.141532692932, 'file_name': 'L01_18879.jpg'}, {'value': 1986.2092280101806, 'file_name': 'L02_46003.jpg'}, {'value': 1831.693169369139, 'file_name': 'L02_6540.jpg'}, {'value': 1695.785561030225, 'file_name': 'L02_86138.jpg'}, {'value': 1511.8505357841607, 'file_name': 'L02_88718.jpg'}, {'value': 1423.5326810022302, 'file_name': 'L02_85838.jpg'}, {'value': 1412.745300421264, 'file_name': 'L01_690.jpg'}, {'value': 1385.5636406428825, 'file_name': 'L01_2670.jpg'}, {'value': 1374.1424152489385, 'file_name': 'L01_29079.jpg'}, {'value': 1373.4056736230646, 'file_name': 'L02_73955.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.6527960734947226,mean_iou=0.5731399663366148
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try3/active_iter1/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try3/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.6012171247518661,mean_iou=0.4954656782290987
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# [Active Learner]: Active learning interation complete, completed iteration:1
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc98d49d090>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc98d49d950>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc98d269fd0>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9c8f59f90>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc98d49da10>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc98d49d710>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc98d49d210>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc98d49de90>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc98d49d350>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc98d49d310>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc98d49d810>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc98d49d510>}
# /content/active_learning_v1/active_learning_try3/active_iter2/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/vali-rsts/L02_51883.png
# mean_dice=0.6322056462113794,mean_iou=0.5449200683726486
# [Active Learner]: the maximum entropy select list:
# [{'value': 1692.240187354897, 'file_name': 'L02_95378.jpg'}, {'value': 1470.5721052460385, 'file_name': 'L02_37221.jpg'}, {'value': 1284.7511164637554, 'file_name': 'L02_19671.jpg'}, {'value': 1276.318059191632, 'file_name': 'L02_6450.jpg'}, {'value': 1219.5963496769882, 'file_name': 'L01_17889.jpg'}, {'value': 1175.483052916803, 'file_name': 'L02_7230.jpg'}, {'value': 1107.4765566048, 'file_name': 'L01_28929.jpg'}, {'value': 1101.9397521126257, 'file_name': 'L02_6360.jpg'}, {'value': 1098.0907111817287, 'file_name': 'L02_27771.jpg'}, {'value': 1080.1419555461289, 'file_name': 'L01_31389.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try3/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6975793057618065,mean_iou=0.6109351177819784
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try3/active_iter2/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try3/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.656389519587253,mean_iou=0.539146527373315
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try3/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# [Active Learner]: Active learning interation complete, completed iteration:2
# Active training ended, validation result:
# [[0.46963753486276094, 0.3882069512645338], [0.5604765747555919, 0.47775760372163806], [0.6322056462113794, 0.5449200683726486]]
# Active training ended, test results:
# DICE:
# [0.611704101429866, 0.6527960734947226, 0.6975793057618065]
# IOU:
# [0.5256899276061883, 0.5731399663366148, 0.6109351177819784]
# IOU_nb:
# [0.4360659018951839, 0.4954656782290987, 0.539146527373315]
# IOU_rs:
# [[0.5128774065238091, 0.15096707228737516], [0.5642409170197897, 0.165651154433583], [0.6048977651730261, 0.12838687832760748]]
# Total time cost(second):
# 3794.7578592300415
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9c3cc67d0>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9c3cc6c50>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9c3cc65d0>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9d471d550>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9c3cc6f50>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9c3cc6310>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9c3cc6e10>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9c3cc6350>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9c3cc6710>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9c3cc6f90>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9c3cc6650>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9c3cc6a90>}
# /content/active_learning_v1/active_learning_try4/active_iter0/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/vali-rsts/L02_51883.png
# mean_dice=0.5010725418938893,mean_iou=0.42698930819762543
# [Active Learner]: the maximum entropy select list:
# [{'value': 2418.321539888021, 'file_name': 'L02_90548.jpg'}, {'value': 2171.7419791476495, 'file_name': 'L02_92288.jpg'}, {'value': 2106.8609205958132, 'file_name': 'L02_76595.jpg'}, {'value': 2078.5812053324644, 'file_name': 'L02_95198.jpg'}, {'value': 2074.575945765916, 'file_name': 'L02_92738.jpg'}, {'value': 1993.0791169560516, 'file_name': 'L02_47053.jpg'}, {'value': 1972.637983073576, 'file_name': 'L02_95168.jpg'}, {'value': 1911.3092283970582, 'file_name': 'L02_65945.jpg'}, {'value': 1897.689992396361, 'file_name': 'L02_85808.jpg'}, {'value': 1863.2053370816843, 'file_name': 'L01_31359.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.6446304936688876,mean_iou=0.5727876817309993
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try4/active_iter0/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try4/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.5871197398251937,mean_iou=0.4830070974334035
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# [Active Learner]: Active learning interation complete, completed iteration:0
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fca5ab62910>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc98d269b50>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fca5ab62650>,
#  'f': <absl.flags._flag.Flag object at 0x7fca5ab62310>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fca5ab58c50>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fca5ab58fd0>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc98d269e10>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc98d269490>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fca5ab581d0>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fca5ab58dd0>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fca5ab587d0>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fca5ab58d10>}
# /content/active_learning_v1/active_learning_try4/active_iter1/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/vali-rsts/L02_51883.png
# mean_dice=0.550019849845661,mean_iou=0.46927677113089666
# [Active Learner]: the maximum entropy select list:
# [{'value': 2849.7977626776574, 'file_name': 'L01_31359.jpg'}, {'value': 2832.757929196111, 'file_name': 'L02_17490.jpg'}, {'value': 2810.325462315822, 'file_name': 'L02_62345.jpg'}, {'value': 2700.5890599043996, 'file_name': 'L01_24759.jpg'}, {'value': 2613.8336003732197, 'file_name': 'L01_31209.jpg'}, {'value': 2561.1455499700232, 'file_name': 'L02_92378.jpg'}, {'value': 2432.4191415689847, 'file_name': 'L01_17460.jpg'}, {'value': 2305.347012930305, 'file_name': 'L02_48583.jpg'}, {'value': 2169.9955451191954, 'file_name': 'L01_10620.jpg'}, {'value': 2162.7943179442273, 'file_name': 'L01_31119.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.6661721402163411,mean_iou=0.5888624075694534
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try4/active_iter1/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try4/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.6060505534338628,mean_iou=0.49931307698751115
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# [Active Learner]: Active learning interation complete, completed iteration:1
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9c3aab490>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9c3aab150>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9c3aab950>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9c959cdd0>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fca5a8fd350>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fca5a8fd690>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9c3aab190>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9c3aab990>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fca5a8fd7d0>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fca5a8fdb90>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9c3aab590>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fca5a8fd650>}
# /content/active_learning_v1/active_learning_try4/active_iter2/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# ...
# mean_dice=0.5936630730690312,mean_iou=0.5171896296722012
# [Active Learner]: the maximum entropy select list:
# [{'value': 2722.0873908491913, 'file_name': 'L02_7830.jpg'}, {'value': 2482.4243336195455, 'file_name': 'L02_92558.jpg'}, {'value': 2254.807042187844, 'file_name': 'L02_92528.jpg'}, {'value': 1948.6216420246296, 'file_name': 'L02_17190.jpg'}, {'value': 1810.3734902541528, 'file_name': 'L01_750.jpg'}, {'value': 1794.4859092858824, 'file_name': 'L02_88448.jpg'}, {'value': 1647.591011049184, 'file_name': 'L02_54103.jpg'}, {'value': 1607.8703231973118, 'file_name': 'L01_31329.jpg'}, {'value': 1590.2093302281053, 'file_name': 'L02_6420.jpg'}, {'value': 1546.4856944653802, 'file_name': 'L02_32121.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter2/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try4/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6941749962826631,mean_iou=0.6277049823721234
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try4/active_iter2/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try4/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6498046114659295,mean_iou=0.5506781049972885
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try4/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# [Active Learner]: Active learning interation complete, completed iteration:2
# Active training ended, validation result:
# [[0.5010725418938893, 0.42698930819762543], [0.550019849845661, 0.46927677113089666], [0.5936630730690312, 0.5171896296722012]]
# Active training ended, test results:
# DICE:
# [0.6446304936688876, 0.6661721402163411, 0.6941749962826631]
# IOU:
# [0.5727876817309993, 0.5888624075694534, 0.6277049823721234]
# IOU_nb:
# [0.4830070974334035, 0.49931307698751115, 0.5506781049972885]
# IOU_rs:
# [[0.5086494405069416, 0.21195934600076707], [0.5459968081581491, 0.19131434300349598], [0.5540226211256386, 0.22735385804530947]]
# Total time cost(second):
# 3821.4723217487335
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9c90bc450>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9c90bce90>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9c90bc990>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9c90bc0d0>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9c9e53650>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9c90bca10>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9c90bcd90>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9c90bccd0>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9c90bce50>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9c90bcd10>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9c90bcbd0>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9c90bcb90>}
# /content/active_learning_v1/active_learning_try5/active_iter0/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/vali-rsts/L02_51883.png
# mean_dice=0.5323604233141076,mean_iou=0.44350110117926217
# [Active Learner]: the maximum entropy select list:
# [{'value': 2502.8534674023595, 'file_name': 'L02_11700.jpg'}, {'value': 2051.2771626758804, 'file_name': 'L02_7830.jpg'}, {'value': 2001.460735658292, 'file_name': 'L02_13380.jpg'}, {'value': 1712.2874932397326, 'file_name': 'L02_30561.jpg'}, {'value': 1653.9569120125307, 'file_name': 'L02_11850.jpg'}, {'value': 1648.6280291953535, 'file_name': 'L02_12300.jpg'}, {'value': 1524.097187631804, 'file_name': 'L01_21669.jpg'}, {'value': 1419.721199408822, 'file_name': 'L02_8280.jpg'}, {'value': 1409.3773001625595, 'file_name': 'L02_21291.jpg'}, {'value': 1376.1712784575489, 'file_name': 'L02_23451.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.6352261138646728,mean_iou=0.5443374435857408
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try5/active_iter0/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try5/active_iter0/test-rsts/L03_18840.png
# mean_dice=0.6040983379302981,mean_iou=0.4874570838954737
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter0/checkpoint/DeepLab_16_240_240/DeepLab.model-1560
#  [*] Success to read DeepLab.model-1560
# [Active Learner]: Active learning interation complete, completed iteration:0
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fc9c3fca210>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fc9c3fca590>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fc9c2e43bd0>,
#  'f': <absl.flags._flag.Flag object at 0x7fc9c75b5dd0>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fc9c3fcadd0>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fc9c3fcac50>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fc9c3fcac10>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fc9c3fcae10>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fc9c3fcaa10>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fc9c3fca850>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fc9c3fca890>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fc9c3fca650>}
# /content/active_learning_v1/active_learning_try5/active_iter1/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/vali-rsts/L02_51883.png
# mean_dice=0.5598567789181258,mean_iou=0.4743146485794121
# [Active Learner]: the maximum entropy select list:
# [{'value': 1947.1270345375228, 'file_name': 'L01_18369.jpg'}, {'value': 1789.3447954526482, 'file_name': 'L02_17190.jpg'}, {'value': 1682.6969711594647, 'file_name': 'L02_8280.jpg'}, {'value': 1674.1102797252688, 'file_name': 'L02_17040.jpg'}, {'value': 1659.2663859889608, 'file_name': 'L01_11940.jpg'}, {'value': 1529.2255577669403, 'file_name': 'L02_18540.jpg'}, {'value': 1511.0613214726982, 'file_name': 'L02_88118.jpg'}, {'value': 1502.926514951339, 'file_name': 'L01_19929.jpg'}, {'value': 1444.4955887126853, 'file_name': 'L02_92288.jpg'}, {'value': 1438.733387128504, 'file_name': 'L02_17070.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.6477336061906865,mean_iou=0.5601483715958023
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try5/active_iter1/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try5/active_iter1/test-rsts/L03_18840.png
# mean_dice=0.621179826127403,mean_iou=0.5086535903828747
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter1/checkpoint/DeepLab_16_240_240/DeepLab.model-2600
#  [*] Success to read DeepLab.model-2600
# [Active Learner]: Active learning interation complete, completed iteration:1
# ||||||||||||||||||||||||||||||||||
# current epoch:
# 520
# ||||||||||||||||||||||||||||||||||
# {'batch_size': <absl.flags._flag.Flag object at 0x7fca5a9f7750>,
#  'checkpoint_dir': <absl.flags._flag.Flag object at 0x7fca5a9f75d0>,
#  'epoch': <absl.flags._flag.Flag object at 0x7fca5a9f7150>,
#  'f': <absl.flags._flag.Flag object at 0x7fca5a9f7910>,
#  'gpu': <absl.flags._flag.Flag object at 0x7fca5a9f7b10>,
#  'img_pattern': <absl.flags._flag.Flag object at 0x7fca5a9f7a90>,
#  'input_height': <absl.flags._flag.Flag object at 0x7fca5a9f7090>,
#  'input_width': <absl.flags._flag.Flag object at 0x7fca5a9f7410>,
#  'label_pattern': <absl.flags._flag.Flag object at 0x7fca5a9f7450>,
#  'pretrain_dir': <absl.flags._flag.Flag object at 0x7fca5a9f7350>,
#  'train_dataset': <absl.flags._flag.Flag object at 0x7fca5a9f7950>,
#  'val_dataset': <absl.flags._flag.Flag object at 0x7fca5a9f7d50>}
# /content/active_learning_v1/active_learning_try5/active_iter2/checkpoint
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/mobilenet_v1_1.0_224/mobilenet_v1_1.0_224.ckpt
#  [*] Load SUCCESS
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/vali-rsts/L02_74165.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/vali-rsts/L02_51103.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/vali-rsts/L02_50683.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/vali-rsts/L02_50233.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/vali-rsts/L02_50203.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/vali-rsts/L02_51493.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/vali-rsts/L02_51883.png
# mean_dice=0.6069775752748514,mean_iou=0.5159622693003889
# [Active Learner]: the maximum entropy select list:
# [{'value': 1514.4892333419616, 'file_name': 'L02_46003.jpg'}, {'value': 1358.6354096114346, 'file_name': 'L02_150.jpg'}, {'value': 1304.2931216153875, 'file_name': 'L02_7770.jpg'}, {'value': 1284.9981224496623, 'file_name': 'L01_24939.jpg'}, {'value': 1134.901122883583, 'file_name': 'L02_42733.jpg'}, {'value': 1123.1109006660513, 'file_name': 'L02_74435.jpg'}, {'value': 1108.9296670880876, 'file_name': 'L02_28731.jpg'}, {'value': 1102.4125682979175, 'file_name': 'L01_18909.jpg'}, {'value': 1042.6718874887056, 'file_name': 'L02_89888.jpg'}, {'value': 1035.0206321714527, 'file_name': 'L01_26139.jpg'}]
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/test-rsts/L03_22410.png
# file not found, file name:
# /content/active_learning_v1/active_learning_try5/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6941490237908071,mean_iou=0.6122845569868847
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try5/active_iter2/test-rsts/L03_22410.png
# [IOU_nb] file not found:
# /content/active_learning_v1/active_learning_try5/active_iter2/test-rsts/L03_18840.png
# mean_dice=0.6276146510524294,mean_iou=0.5136704135258975
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from /content/active_learning_v1/active_learning_try5/active_iter2/checkpoint/DeepLab_16_240_240/DeepLab.model-3120
#  [*] Success to read DeepLab.model-3120
# [Active Learner]: Active learning interation complete, completed iteration:2
# Active training ended, validation result:
# [[0.5323604233141076, 0.44350110117926217], [0.5598567789181258, 0.4743146485794121], [0.6069775752748514, 0.5159622693003889]]
# Active training ended, test results:
# DICE:
# [0.6352261138646728, 0.6477336061906865, 0.6941490237908071]
# IOU:
# [0.5443374435857408, 0.5601483715958023, 0.6122845569868847]
# IOU_nb:
# [0.4874570838954737, 0.5086535903828747, 0.5136704135258975]
# IOU_rs:
# [[0.4887278396292871, 0.16827565180845513], [0.5182873597839128, 0.17502480526297695], [0.5705589318254383, 0.180383369378895]]
# Total time cost(second):
# 3814.1399896144867
# Active training ended, final test results of all attemptions:
# DICE of each trail:
# [[0.6149097202088339, 0.5457024574347593, 0.6242105967114424], [0.6178914682695235, 0.6430344765000894, 0.6977280400991852], [0.611704101429866, 0.6527960734947226, 0.6975793057618065], [0.6446304936688876, 0.6661721402163411, 0.6941749962826631], [0.6352261138646728, 0.6477336061906865, 0.6941490237908071]]
# Final IOU of each trail:
# [[0.5294613736905157, 0.4653686190082805, 0.5472601256192745], [0.5583551295090197, 0.5743097926158467, 0.6314830724663485], [0.5256899276061883, 0.5731399663366148, 0.6109351177819784], [0.5727876817309993, 0.5888624075694534, 0.6277049823721234], [0.5443374435857408, 0.5601483715958023, 0.6122845569868847]]
# Final IOU_nb of each trail:
# [[0.47500823829546246, 0.36982792913985113, 0.4634835689786261], [0.46900015941023754, 0.4829432124951335, 0.5588130416655331], [0.4360659018951839, 0.4954656782290987, 0.539146527373315], [0.4830070974334035, 0.49931307698751115, 0.5506781049972885], [0.4874570838954737, 0.5086535903828747, 0.5136704135258975]]
# Result of the final result:
# Dice:
# [0.6242106  0.69772804 0.69757931 0.694175   0.69414902]
# IOU:
# [0.54726013 0.63148307 0.61093512 0.62770498 0.61228456]
# IOU NB:
# [0.46348357 0.55881304 0.53914653 0.5506781  0.51367041]

# %%
sys.exit()
print('active training complete, begin to copy files')
# %cp -ar '/content/active_learning_v1' '/content/drive/MyDrive/active_learning_ws/active_learning_v1/test_attempts'
print('Copy files complete')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# al.create_folder(path_workspace)
# folder_workspace = path_workspace + '/active_learning_try1'
# al.delete_folder(folder_workspace)
# al.delete_folder('/content/active_learning_v1/background_for_syn_live')
# al.delete_folder('/content/active_learning_v1/mobilenet_v1_1.0_224')
# al.create_folder(folder_workspace)

# !unzip -q "/content/drive/MyDrive/active_learning_ws/data/database_folder12_l.zip" -d '/content/active_learning_v1/active_learning_try1'
# !unzip -q "/content/drive/MyDrive/active_learning_ws/data/background_for_syn_folder12_l.zip" -d '/content/active_learning_v1/active_learning_try1'
# !unzip -q "/content/drive/MyDrive/active_learning_ws/active_learning_v1/mobilenet_v1_1.0_224.zip" -d '/content/active_learning_v1'

# shutil.copy("/content/drive/MyDrive/active_learning_ws/active_learning_v1/labels.json", 
#             "/content/active_learning_v1/labels.json")
